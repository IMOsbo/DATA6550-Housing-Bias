# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

import datetime as dt

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %matplotlib inline

pd.set_option('display.max_columns', 250) 
plt.style.use('seaborn-v0_8-pastel')

# %% [markdown]
# ## Checking Dataset

# %%
df_mortgage = pd.read_csv("../../Data/mortgage_covenant_data.csv")

# %%
df_mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100931 entries, 0 to 100930
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   activity_year                      100931 non-null  int64
#  1   census_tract                       99915 non-null   float64
#  2   derived_race                       100931 non-null  object
#  3   action_taken                       100931 non-null  int64
#  4   loan_amount                        100931 non-null  float64
#  5   property_value                     83491 non-null   float64
#  6   income                             88200 non-null   float64
#  7   interest_rate                      78125 non-null   float64
#  8   tract_minority_population_percent  100931 non-null  float64
#  9   tract_to_msa_income_percentage     100931 non-null  float64
#  10  denial_reason-1                    100931 non-null  int64
# ...

# %%
df_mortgage
# Out:
#         activity_year  census_tract        derived_race  action_taken  \
# 0                2023  2.703706e+10  Race Not Available             6
# 1                2023  2.714103e+10  Race Not Available             6
# 2                2023  2.702395e+10  Race Not Available             6
# 3                2023  2.717110e+10  Race Not Available             6
# 4                2023  2.715948e+10  Race Not Available             6
# ...               ...           ...                 ...           ...
# 100926           2023  2.700902e+10  Race Not Available             6
# 100927           2023  2.706778e+10  Race Not Available             6
# 100928           2023  2.714948e+10  Race Not Available             6
# 100929           2023  2.705913e+10  Race Not Available             6
# 100930           2023  2.703595e+10  Race Not Available             6
#
#         loan_amount  property_value  income  interest_rate  \
# 0          185000.0        195000.0     NaN          6.125
# ...

# %% [markdown]
# ## Algorithmic Bias

# %% [markdown]
# ### Approval Rates by Race

# %%
approval_rates = df_mortgage.groupby("derived_race")["was_approved"].mean()
print("Approval rates by race:\n", approval_rates)
# Out:
# Approval rates by race:
#  derived_race
# 2 or more minority races                     0.659259
# American Indian or Alaska Native             0.622003
# Asian                                        0.707705
# Black or African American                    0.604155
# Free Form Text Only                          0.800000
# Joint                                        0.744129
# Native Hawaiian or Other Pacific Islander    0.566372
# Race Not Available                           0.405725
# White                                        0.756063
# Name: was_approved, dtype: float64

# %% [markdown]
# ### Creating X and y datasets

# %%
#Converting 'was_approved' into 1s and 0s for analysis True -> 1, False -> 0
df_mortgage["was_approved"] = df_mortgage["was_approved"].astype(int)

# Check the unique values after conversion
print("After conversion:", df_mortgage["was_approved"].unique())
# Out:
# After conversion: [0 1]

# %%
#Creating dummy variables
dummies_race = pd.get_dummies(df_mortgage['derived_race'], drop_first = False, dtype='int')
df_mortgage = pd.concat([df_mortgage, dummies_race], axis = 1)

# %%
df_mortgage
# Out:
#         activity_year  census_tract        derived_race  action_taken  \
# 0                2023  2.703706e+10  Race Not Available             6
# 1                2023  2.714103e+10  Race Not Available             6
# 2                2023  2.702395e+10  Race Not Available             6
# 3                2023  2.717110e+10  Race Not Available             6
# 4                2023  2.715948e+10  Race Not Available             6
# ...               ...           ...                 ...           ...
# 100926           2023  2.700902e+10  Race Not Available             6
# 100927           2023  2.706778e+10  Race Not Available             6
# 100928           2023  2.714948e+10  Race Not Available             6
# 100929           2023  2.705913e+10  Race Not Available             6
# 100930           2023  2.703595e+10  Race Not Available             6
#
#         loan_amount  property_value  income  interest_rate  \
# 0          185000.0        195000.0     NaN          6.125
# ...

# %%
# Define the sensitive attribute
sensitive_feature = df_mortgage["derived_race"]

X = df_mortgage.drop(['activity_year', 'census_tract', 'derived_race', 'action_taken', 'loan_amount', 'property_value',
                     'income', 'interest_rate', 'denial_reason-1', 'covenant_density', 'was_approved'], axis = 1)

y = df_mortgage['was_approved']

# %%
X
# Out:
#         tract_minority_population_percent  tract_to_msa_income_percentage  \
# 0                                   40.37                           73.48
# 1                                   10.64                          121.26
# 2                                    8.92                           90.13
# 3                                   13.27                          104.37
# 4                                    5.87                           82.22
# ...                                   ...                             ...
# 100926                               4.88                          106.18
# 100927                              46.58                           74.68
# 100928                              20.14                          118.83
# 100929                               6.84                           90.07
# 100930                               5.64                          106.15
#
#         covenant_count  2 or more minority races  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, sensitive_train, sensitive_test = train_test_split(X, y, sensitive_feature, test_size=0.3, random_state=42)

# %%
#Checking training and test sets.
print('---------------------------------------------------------------')
print('y training set' + str(y_train.shape))
print('y test set' + str(y_test.shape))
print('Shape of y' + str(y.shape))
print('---------------------------------------------------------------')
print('***************************************************************')
print('X training set' + str(X_train.shape))
print('X test set' + str(X_test.shape))
print('Shape of X' + str(X.shape))

print('---------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------
# y training set(70651,)
# y test set(30280,)
# Shape of y(100931,)
# ---------------------------------------------------------------
# ***************************************************************
# X training set(70651, 12)
# X test set(30280, 12)
# Shape of X(100931, 12)
# ---------------------------------------------------------------

# %% [markdown]
# ### Decision Tree and Random Forest Models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from fairlearn.metrics import MetricFrame, selection_rate, true_positive_rate, false_positive_rate

#Decision Tree Model
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(X_train, y_train)
y_pred_dt = dt_clf.predict(X_test)

#Random Forest Model
rf_clf = RandomForestClassifier(random_state=42, n_estimators=100)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)

#Overall accuracy for both models
acc_dt = accuracy_score(y_test, y_pred_dt)
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Decision Tree Accuracy:", acc_dt)
print("Random Forest Accuracy:", acc_rf)

# Define fairness metrics to evaluate
metrics = {
    "selection_rate": selection_rate,
    "true_positive_rate": true_positive_rate,
    "false_positive_rate": false_positive_rate
}

# Evaluate fairness metrics for Decision Tree
metric_frame_dt = MetricFrame(
    metrics=metrics,
    y_true=y_test,
    y_pred=y_pred_dt,
    sensitive_features=sensitive_test
)
print("\nFairness Metrics for Decision Tree by Derived Race:")
print(metric_frame_dt.by_group)

# Evaluate fairness metrics for Random Forest
metric_frame_rf = MetricFrame(
    metrics=metrics,
    y_true=y_test,
    y_pred=y_pred_rf,
    sensitive_features=sensitive_test
)
print("\nFairness Metrics for Random Forest by Derived Race:")
print(metric_frame_rf.by_group)
# Out:
# Decision Tree Accuracy: 0.6938243064729194
# Random Forest Accuracy: 0.6963342140026421
#
# Fairness Metrics for Decision Tree by Derived Race:
#                                            selection_rate  true_positive_rate  \
# derived_race
# 2 or more minority races                         0.631579            0.600000
# American Indian or Alaska Native                 0.548837            0.567376
# Asian                                            0.811562            0.818253
# Black or African American                        0.682510            0.676379
# Free Form Text Only                              0.000000            0.000000
# Joint                                            0.707692            0.693609
# Native Hawaiian or Other Pacific Islander        0.483871            0.533333
# Race Not Available                               0.222499            0.250629
# White                                            0.971797            0.985223
#
# ...

# %%
print("Approval rates by race:\n", approval_rates)
# Out:
# Approval rates by race:
#  derived_race
# 2 or more minority races                     0.659259
# American Indian or Alaska Native             0.622003
# Asian                                        0.707705
# Black or African American                    0.604155
# Free Form Text Only                          0.800000
# Joint                                        0.744129
# Native Hawaiian or Other Pacific Islander    0.566372
# Race Not Available                           0.405725
# White                                        0.756063
# Name: was_approved, dtype: float64

# %% [markdown]
# #### Graphing Predicted vs Actual Rates

# %%
#Compute actual approval rate
actual_rate = y_test.groupby(sensitive_test).mean()

#Compute predicted approval rate for decision tree model
predicted_rate_dt = pd.Series(y_pred_dt, index=y_test.index).groupby(sensitive_test).mean()

#Compute predicted approval rate for random forest model
predicted_rate_rf = pd.Series(y_pred_rf, index=y_test.index).groupby(sensitive_test).mean()

#Creating dataframe with computed rates
df_rates = pd.DataFrame({
    'derived_race': actual_rate.index,
    'Actual': actual_rate.values,
    'Decision Tree': predicted_rate_dt.values,
    'Random Forest': predicted_rate_rf.values
})

#Melt dataframe to long format for seaborn barplot
df_melted = df_rates.melt(id_vars='derived_race', var_name='Model', value_name='Approval Rate')

#Grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=df_melted, x='derived_race', y='Approval Rate', hue='Model')

plt.xticks(rotation=45)

plt.title("Predicted vs Actual Approval Rates by Derived Race")
plt.xlabel("Derived Race")
plt.ylabel("Approval Rate")
plt.legend(title="Model")
plt.show()

# %% [markdown]
# #### Feature Importance

# %%
#Computing and displaying feature importance
importances = rf_clf.feature_importances_
features = X.columns
feature_importance_df = pd.DataFrame({"feature": features, "importance": importances})
feature_importance_df = feature_importance_df.sort_values(by="importance", ascending=False)
print("\nTop 10 Important Features:")
print(feature_importance_df.head(10))

#Top 10 important features
plt.figure(figsize=(10, 6))
sns.barplot(x="importance", y="feature", data=feature_importance_df.head(10))
plt.title("Top 10 Important Features in Risk Assessment")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()
# Out:
# Top 10 Important Features:
#                               feature  importance
# 0   tract_minority_population_percent    0.295390
# 1      tract_to_msa_income_percentage    0.287645
# 10                 Race Not Available    0.224296
# 11                              White    0.127439
# 2                      covenant_count    0.029362
# 5                               Asian    0.013168
# 6           Black or African American    0.009983
# 8                               Joint    0.009351
# 4    American Indian or Alaska Native    0.001860
# 3            2 or more minority races    0.000794

# %%
import scipy.stats as stats


#Summary stats for interest_rate
group_summary = df_mortgage.groupby('derived_race')['interest_rate'].agg(['mean', 'median', 'std', 'count'])
print("Summary statistics by Derived Race:")
print(group_summary)

#Boxplot of interest_rate by derived_race
plt.figure(figsize=(10, 6))
sns.boxplot(x='derived_race', y='interest_rate', data=df_mortgage)
plt.title("Distribution of Interest Rate by Derived Race")
plt.xlabel("Derived Race")
plt.ylabel("Interest Rate")

plt.xticks(rotation=45)

plt.show()

#ANOVA test to see if interest rates differ significantly across groups
groups = [group["interest_rate"].dropna() for name, group in df_mortgage.groupby("derived_race")]
f_stat, p_val = stats.f_oneway(*groups)
print("\nANOVA Test Results:")
print("F-statistic:", f_stat)
print("p-value:", p_val)
# Out:
# Summary statistics by Derived Race:
#                                                mean  median       std  count
# derived_race
# 2 or more minority races                   6.169189  6.6250  1.854802     95
# American Indian or Alaska Native           6.565429  6.8750  1.762900    476
# Asian                                      6.482825  6.6250  1.282522   4460
# Black or African American                  6.306014  6.6250  1.608089   3700
# Free Form Text Only                        6.216250  5.9375  1.433082      4
# Joint                                      6.599419  6.6250  1.222371   1917
# Native Hawaiian or Other Pacific Islander  6.665772  6.8750  1.290442     79
# Race Not Available                         6.586252  6.6250  1.302485  17967
# White                                      6.599305  6.7400  1.224264  49427
# ANOVA Test Results:
# F-statistic: 27.460426953464086
# p-value: 5.1972936530620905e-43
